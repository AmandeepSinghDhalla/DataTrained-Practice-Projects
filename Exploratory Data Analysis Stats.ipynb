# %% [markdown]
# # Exploratory Data Anaylsis (EDA)

# %% [markdown]
# EDA is the data analysis approach where we explore the main characteristics of the data and draw insights from them after the visualisation and testing.  EDA is used to find main features, the relationship between different variables, identifing which variables are important for our problems.
#
# Various libraries like pandas, seaborn, matplootlib etc are used for EDA. We perform:
#
# 1 Read Data
#
# 2 Variable Identification, Looking the input data, what willl be the output variable.
#
# 3 Unvariate Analysis- Bar plot, Histogram plot(column exploration)
#
# 4 Bivariate analysis- Scatter plot, pair plot(more visualisation)
#
# 5 Detecting outliers/anamoly detection
#
# 6 Removing null values/ finding missing values
#
# 7 handling categorical variables

# %% [markdown]
# # 1 Read Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
ds = pd.read_csv('redwine.csv')
ds # dataset has 1599 rows an 12 columns
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# Now first of all we check the characteristics of the dataset.

# %%
ds.dtypes # gives us the data types for each column
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
ds.info()
#ds.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# Summary Stats

# %% [markdown]
# Now we use describe to see some basic insights and draw thew characteristics of the dataset.

# %% [markdown]
# # 2 Variable Identification, Looking the input data, what willl be the output variable.

# %%
ds.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [raw]
# From the above data following insights can be drawn :
#     1 when the standard deviation is more in the data, it means that the data is more spreaded.
#     2 when there is a large difference between the minimum value and 25 percentile, it means that outliers are present.
#     3 when mean is higher than median or 50 percentile, it means that the data is right skwewed.
#     4 high difference between 75th percentile and max value again shows the presence of outliers.

# %% [markdown]
# Now we use some more functions to draw out more information

# %%
ds['quality'].unique() #it shows that ther eare 6 unique qualities of wine from 3 to 8.
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
# Now we will use value_count function to see that which quality of wine are the most in number.
ds['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [raw]
# From the above two function we get info that :
#     1 There are total 6 quality of wine from 3 to 8
#     2 Majority of the wine is of quality 5 then 6 then 7
#     3 Minority of the wine is of quality 3 then 8 then 4

# %% [markdown]
# Using data visualisation for analysis.

# %% [markdown]
# First of all we check if there is any missing value in the data. for that we use function "isnull". Then we visualise that data.

# %%
#ds.isnull()
sns.heatmap(ds.isnull()) # as we see from the plot that there is no data missing in the dataset.
# Out:
# <AxesSubplot:>

# %%
#sns.heatmap?
#sns.color_palette?

# %% [markdown]
# Now we check the correlation of the dataset. It will give us the relationship between different columns of the dataset.

# %%
sns.heatmap(ds.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The above plot shows us the correlation of the dataset between different columns.

# %% [markdown]
# Now, if we want to put the values of the data inside the heat map, then we have an arrgument in the nss.heatmap function where by default "annot = False". annot means Annotate, so if we want the data values inside the heatmap, when switch value of annotate to true, so "annot = True".
#
# We can also change the colour scheme using cmap.
#
# If the figure is small then we can incresae the figure size using the syntax : plt.figure(figsize = (a,b))  before the ploting. a and b are the dimension of the figure size.

# %%
plt.figure(figsize = (8,6))
sns.heatmap(ds.corr(), cmap = 'Greens', annot = True) # since annot is true, data is put into plot
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 3 Unvariate Analysis- Bar plot, Histogram plot(column exploration)
# # Will tell us about the outliers

# %% [markdown]
# Now we perform the univariate analysis. In univariate analysis, we look at each coluumn seperately, we plot the box plot and look for outliers

# %%
sns.boxplot(ds['fixed acidity'], color = 'green')
# Out:
# <AxesSubplot:xlabel='fixed acidity'>

# %%
sns.boxplot(ds['citric acid'])
# Out:
# <AxesSubplot:xlabel='citric acid'>

# %% [markdown]
# We can plot each and every column one by one by writing codes or we can plot each and every column seperately using one function. As shown below

# %% [raw]
# Now we have a "subplot" function which is present in matplotlib.pyplot. With the help of this subplot function, we can combine and plot multiple figures either side by side or on top of each other. The syntax for the subplotis as such:
#
#                                 subplot(no_of_rows, no_of,columns, index_of_plot)
#
# no_of_rows is the total number of rows that we want in the complete figure.
#
# similarly, no_of_rows is the total number of columns that we want in the complete figure.
#
# index_of_plot is the indexing of the plot that we want one after the another. For example in the figure given below, we want to subplot all the boxplots of the columns in the data set "redwine.csv". So In order to acheive that, we first make a array of names of columns using "clist = ds.columns.values". Then, in the index_of_plot we put clist[i] such that all the column names are provided one by one and then there box plot can be ploted using subplot.
#
# After that, we simply use the type of plot that we want and as we can see in output all the figure is obtained side by side.
#
# The size of the graph is adjusted using the plt.figure(figsize = (a, b)) function

# %%
clist = ds.columns.values
plt.figure(figsize = (20, 70))
for i in range(0 , len(clist)):
    plt.subplot(8,12, i + 1 )
    sns.boxplot(ds[clist[i]], color = 'yellow')
    #plt.tight_layout()

# %% [markdown]
# Outliers are present are are removed in the very first step before checking skewness. Removing the outliers may also remove the skewness from the data.

# %% [markdown]
# # To check skewness of Data

# %% [markdown]
# Now we can check the skewness of the data using distribution plot one by one.

# %%
sns.distplot(ds['fixed acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(ds['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %% [markdown]
# We can also use subplot to draw the data side by side. As shown below.

# %%
plt.figure(figsize = (18, 8))
for i in range(0, len(clist)):
    plt.subplot(4, 12, i + 1)
    sns.distplot(ds[clist[i]], color = 'red')

# %% [markdown]
# From the above plots, we can see that only density and ph of the data is normally distributed, rest of the features of the wine are skewed one way or another.
